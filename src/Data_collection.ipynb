# %%
import pandas as pd
import seaborn as sns

import numpy as np
import matplotlib.pyplot as plt

from scipy.stats import pearsonr
from scipy.stats import spearmanr

# %% [markdown]
# # Data collection and preprosessing
#
# For this project we will collect data from three sources. All three data sets are of protein sequences with experimental TM (melting temperature). The three data sets will all be combined before further processing.

# %% [markdown]
# ## Meltome atlas data
#
# This data was provided as a csv file with gene names and uniprot ids and TM values. Thus we need to first download and map the sequences for this data set.

# %%
file_c="../data/MeltomAtlas/cross-species.csv"

df_c = pd.read_csv(file_c)


df_c = df_c.dropna(subset=['meltPoint'])
df_c_nonan = df_c.dropna()

# write query column with uniprot id
df_c_nonan['query'] = df_c_nonan['Protein_ID'].apply(lambda x: x.split('_')[0])

# Drop duplicates
df_c_noredun = df_c_nonan.drop_duplicates(subset=['query'])
df_TM = df_c_nonan.groupby('query')['meltPoint'].median().to_frame()
# Out:
# /tmp/ipykernel_27010/2097973913.py:3: DtypeWarning: Columns (1,4) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_c = pd.read_csv(file_c)
# /tmp/ipykernel_27010/2097973913.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_c_nonan['query'] = df_c_nonan['Protein_ID'].apply(lambda x: x.split('_')[0])

# %% [markdown]
# ### Separate human part
#
# Human part needs to be treated diferently since only gene name is used as identifier not uniprot id

# %%
df_h = df_c[df_c['run_name'].str.match('Homo sapiens')]

# %% [markdown]
# ### Make the data non redundant
#
# There are several measurments of the same gene, so we need to only grab the median value of the measured melting temperatures for each gene.

# %%
df_h_noredu = df_h.groupby('gene_name')['meltPoint'].median().to_frame()
df_h_noredu.to_csv("human_TM.csv")

# %% [markdown]
# ### Save text file with gene names

# %%
with open("../data/MeltomAtlas/gene_names.txt", "w") as file_writer:
    for row in df_h_noredu.iterrows():
        gene_name = row[0]
        file_writer.write(f"{gene_name}\n")

# %% [markdown]
# ### Save ID non human

# %%
with open("../data/MeltomAtlas/gene_names_nohuman.txt", "w") as file_writer:
    for row in df_c_nonan.iterrows():
        gene_name = row[1]['Protein_ID']
        file_writer.write(f"{gene_name.split('_')[0]}\n")

# %% [markdown]
# ### Download seq data from ids

# %%
# fetch all ids from the nonredundant df
list_ids = []
for row in df_c_noredun.iterrows():
    gene_name = row[1]['Protein_ID']
    list_ids.append(f"{gene_name.split('_')[0]}")

# %%
from Bio import SeqIO
from multiprocessing import Pool

# Fetch all ids from uniprot
IDS = [f"{id_}"  for idx, id_ in enumerate(list_ids)]

def fetch(id_):
    rec  = ! curl -s https://rest.uniprot.org/uniprotkb/{id_}.fasta
    return rec
with Pool(16) as p:
    list_rec = p.map(fetch, IDS)
#print(f"Done fetching all {idx} sequences")

# %%
df_rec = {}

for rec in list_rec:
    if len(rec) > 2:
        id_ = rec[0].split("|")[1]
        df_rec[id_]=("".join([s for s in rec[1:]]) , rec[0])

len(df_rec)
# Out:
# 24262

# %% [markdown]
# ### Write fasta file

# %%
#Write all downloaded entries 

data_set = "meltome_atlas"
with open(f"../data/MeltomAtlas/{data_set}_TM.fasta", "w") as file_writer:
    for rec in df_TM.iterrows():
        id_ = rec[0]
        TM = rec[1]['meltPoint']


        try:
            seq = df_rec[id_][0]
            #print(f"ID: {id_}\tTM: {TM}\tSeq: {seq}")
# Id: Q80XU2 does not exist
# Id: Q86NB3 does not exist
# Id: Q8CEJ2 does not exist
# Id: Q8CFB8 does not exist
# Id: Q8I4C5 does not exist
# Id: Q8IA49 does not exist
# Id: Q8MPS2 does not exist
# Id: Q8MXS2 does not exist
# Id: Q8WQE0 does not exist
# Id: Q93HR1 does not exist
# Id: Q95QZ7 does not exist
# Id: Q95XU3 does not exist
# Id: Q99J19 does not exist
# Id: Q99M46 does not exist
# Id: Q9JIS3 does not exist
# Id: Q9JJQ6 does not exist
# Id: Q9MGM1 does not exist
# Id: Q9N3K6 does not exist
# Id: Q9N5X8 does not exist
# Id: Q9NA30 does not exist
# Id: Q9TYP3 does not exist
# Id: Q9TYZ1 does not exist
# Id: Q9U2V9 does not exist
# Id: Q9UAN9 does not exist
# Id: Q9VH69 does not exist
# Id: Q9XWZ9 does not exist
# Id: Q9XZQ2 does not exist
# Id: Q9XZQ7 does not exist
# Id: Q9ZND7 does not exist
# Id: R4YV43 does not exist
# Id: S5ZDJ9 does not exist
# Id: U4PF53 does not exist
# Id: V6CK76 does not exist
# Id: V6CLC9 does not exist
# Id: V6CLU0 does not exist
# Id: V9GXK0 does not exist
# Id: X5LVB3 does not exist

# %%
# Check the total written entries in fasta file
! grep "^>" TM.fasta | wc
# Out:
#   24262   72786  950233

# %% [markdown]
# ## Combine Meltome atlas data with data from the other sets

# %%
! if [ -f "TM.fasta" ]; then mv TM.fasta ../data/data_Tm/meltome_atlas_TM.fasta; fi

# %%
! cat ../data/MeltomAtlas/meltome_atlas_TM.fasta > ../data/all_tms.fasta
! cat ../data/JarZab/cleaned_enzyme_tms_jarzab_v1.fasta >> ../data/all_tms.fasta
! cat ../data/Leuenberger/cleaned_enzyme_tms_v1.fasta >> ../data/all_tms.fasta

# %% [markdown]
# ## Make the combined data set non redundant
# When Using CD-Hit (95%)

# %%
! cd-hit -i ../data/all_tms.fasta -o ../data/all_tms_noredun.fasta -c 0.99 -T 10
# Out:
# ================================================================
# Program: CD-HIT, V4.8.1 (+OpenMP), Apr 07 2021, 10:57:21
# Command: cd-hit -i ../data/all_tms.fasta -o
#          ../data/all_tms_noredun.fasta -c 0.99 -T 10
#
# Started: Mon Jun 12 18:22:30 2023
# ================================================================
#                             Output
# ----------------------------------------------------------------
# total seq: 68493
# longest and shortest : 35213 and 31
# Total letters: 33259678
# Sequences have been sorted
#
# Approximated minimal memory consumption:
# Sequence        : 41M
# Buffer          : 10 X 18M = 188M
# Table           : 2 X 66M = 132M
# Miscellaneous   : 0M
# Total           : 363M
#
# Table limit with the given memory limit:
# Max number of representatives: 592200
# Max number of word counting entries: 54572295
#
# # comparing sequences from          0  to       4557
# ....---------- new table with     3058 representatives
# # comparing sequences from       4557  to       9885
# ----------   3846 remaining sequences to the next cycle
# ---------- new table with      932 representatives
# # comparing sequences from       6039  to      11243
# ----------   4383 remaining sequences to the next cycle
# ---------- new table with      503 representatives
# # comparing sequences from       6860  to      11996
# ----------   4380 remaining sequences to the next cycle
# ---------- new table with      471 representatives
# # comparing sequences from       7616  to      12689
# ----------   4360 remaining sequences to the next cycle
# ---------- new table with      436 representatives
# # comparing sequences from       8329  to      13342
# ----------   4216 remaining sequences to the next cycle
# ---------- new table with      506 representatives
# # comparing sequences from       9126  to      14073
# ----------   4141 remaining sequences to the next cycle
# ---------- new table with      481 representatives
# # comparing sequences from       9932  to      14812
# ..........    10000  finished       6426  clusters
# ----------   4085 remaining sequences to the next cycle
# ---------- new table with      481 representatives
# # comparing sequences from      10727  to      15540
# ----------   3981 remaining sequences to the next cycle
# ---------- new table with      517 representatives
# # comparing sequences from      11559  to      16303
# ----------   3945 remaining sequences to the next cycle
# ---------- new table with      476 representatives
# # comparing sequences from      12358  to      17035
# ----------   3844 remaining sequences to the next cycle
# ---------- new table with      503 representatives
# # comparing sequences from      13191  to      17799
# ----------   3820 remaining sequences to the next cycle
# ---------- new table with      484 representatives
# # comparing sequences from      13979  to      18521
# ----------   3745 remaining sequences to the next cycle
# ---------- new table with      476 representatives
# # comparing sequences from      14776  to      19252
# ----------   3716 remaining sequences to the next cycle
# ---------- new table with      449 representatives
# # comparing sequences from      15536  to      19949
# ----------   3607 remaining sequences to the next cycle
# ---------- new table with      487 representatives
# # comparing sequences from      16342  to      20687
# ----------   3579 remaining sequences to the next cycle
# ---------- new table with      444 representatives
# # comparing sequences from      17108  to      21390
# ----------   3468 remaining sequences to the next cycle
# ---------- new table with      490 representatives
# # comparing sequences from      17922  to      22136
# ----------   3431 remaining sequences to the next cycle
# ---------- new table with      481 representatives
# # comparing sequences from      18705  to      22854
# ----------   3328 remaining sequences to the next cycle
# ---------- new table with      478 representatives
# # comparing sequences from      19526  to      23606
# ..........    20000  finished      12437  clusters
# ----------   3343 remaining sequences to the next cycle
# ---------- new table with      443 representatives
# # comparing sequences from      20263  to      24282
# ----------   3246 remaining sequences to the next cycle
# ---------- new table with      461 representatives
# # comparing sequences from      21036  to      24990
# ----------   3263 remaining sequences to the next cycle
# ---------- new table with      400 representatives
# # comparing sequences from      21727  to      25624
# ----------   3136 remaining sequences to the next cycle
# ---------- new table with      433 representatives
# # comparing sequences from      22488  to      26321
# ----------   3123 remaining sequences to the next cycle
# ---------- new table with      426 representatives
# # comparing sequences from      23198  to      26972
# ----------   3020 remaining sequences to the next cycle
# ---------- new table with      440 representatives
# # comparing sequences from      23952  to      27663
# ----------   2987 remaining sequences to the next cycle
# ---------- new table with      426 representatives
# # comparing sequences from      24676  to      28327
# ----------   2949 remaining sequences to the next cycle
# ---------- new table with      410 representatives
# # comparing sequences from      25378  to      28970
# ----------   2933 remaining sequences to the next cycle
# ---------- new table with      376 representatives
# # comparing sequences from      26037  to      29575
# ----------   2838 remaining sequences to the next cycle
# ---------- new table with      411 representatives
# # comparing sequences from      26737  to      30216
# ----------   2770 remaining sequences to the next cycle
# ---------- new table with      402 representatives
# # comparing sequences from      27446  to      30866
# ----------   2724 remaining sequences to the next cycle
# ---------- new table with      404 representatives
# # comparing sequences from      28142  to      31504
# ----------   2755 remaining sequences to the next cycle
# ---------- new table with      354 representatives
# # comparing sequences from      28749  to      32061
# ----------   2638 remaining sequences to the next cycle
# ---------- new table with      377 representatives
# # comparing sequences from      29423  to      32678
# ..........    30000  finished      18239  clusters
# ----------   2632 remaining sequences to the next cycle
# ---------- new table with      336 representatives
# # comparing sequences from      30046  to      33249
# ----------   2568 remaining sequences to the next cycle
# ---------- new table with      355 representatives
# # comparing sequences from      30681  to      33832
# ----------   2521 remaining sequences to the next cycle
# ---------- new table with      381 representatives
# # comparing sequences from      31311  to      34409
# ----------   2452 remaining sequences to the next cycle
# ---------- new table with      368 representatives
# # comparing sequences from      31957  to      35001
# ----------   2418 remaining sequences to the next cycle
# ---------- new table with      347 representatives
# # comparing sequences from      32583  to      35575
# ----------   2319 remaining sequences to the next cycle
# ---------- new table with      387 representatives
# # comparing sequences from      33256  to      36192
# ----------   2304 remaining sequences to the next cycle
# ---------- new table with      351 representatives
# # comparing sequences from      33888  to      36771
# ----------   2246 remaining sequences to the next cycle
# ---------- new table with      365 representatives
# # comparing sequences from      34525  to      37355
# ----------   2202 remaining sequences to the next cycle
# ---------- new table with      353 representatives
# # comparing sequences from      35153  to      37931
# ----------   2170 remaining sequences to the next cycle
# ---------- new table with      354 representatives
# # comparing sequences from      35761  to      38488
# ----------   2114 remaining sequences to the next cycle
# ---------- new table with      346 representatives
# # comparing sequences from      36374  to      39050
# ----------   2090 remaining sequences to the next cycle
# ---------- new table with      318 representatives
# # comparing sequences from      36960  to      39587
# ----------   2078 remaining sequences to the next cycle
# ---------- new table with      311 representatives
# # comparing sequences from      37509  to      40091
# ----------   2006 remaining sequences to the next cycle
# ---------- new table with      334 representatives
# # comparing sequences from      38085  to      40619
# ----------   2015 remaining sequences to the next cycle
# ---------- new table with      285 representatives
# # comparing sequences from      38604  to      41094
# ----------   1979 remaining sequences to the next cycle
# ---------- new table with      290 representatives
# # comparing sequences from      39115  to      41563
# ----------   1998 remaining sequences to the next cycle
# ---------- new table with      278 representatives
# # comparing sequences from      39565  to      41975
# ..........    40000  finished      23907  clusters
# ----------   1846 remaining sequences to the next cycle
# ---------- new table with      304 representatives
# # comparing sequences from      40129  to      42492
# ----------   1866 remaining sequences to the next cycle
# ---------- new table with      301 representatives
# # comparing sequences from      40626  to      42948
# ----------   1769 remaining sequences to the next cycle
# ---------- new table with      304 representatives
# # comparing sequences from      41179  to      43455
# ----------   1777 remaining sequences to the next cycle
# ---------- new table with      285 representatives
# # comparing sequences from      41678  to      43912
# ----------   1691 remaining sequences to the next cycle
# ---------- new table with      296 representatives
# # comparing sequences from      42221  to      44410
# ----------   1684 remaining sequences to the next cycle
# ---------- new table with      291 representatives
# # comparing sequences from      42726  to      44873
# ----------   1608 remaining sequences to the next cycle
# ---------- new table with      308 representatives
# # comparing sequences from      43265  to      45367
# ----------   1595 remaining sequences to the next cycle
# ---------- new table with      289 representatives
# # comparing sequences from      43772  to      45832
# ----------   1617 remaining sequences to the next cycle
# ---------- new table with      234 representatives
# # comparing sequences from      44215  to      46238
# ----------   1591 remaining sequences to the next cycle
# ---------- new table with      268 representatives
# # comparing sequences from      44647  to      46634
# ----------   1531 remaining sequences to the next cycle
# ---------- new table with      262 representatives
# # comparing sequences from      45103  to      47052
# ----------   1477 remaining sequences to the next cycle
# ---------- new table with      256 representatives
# # comparing sequences from      45575  to      47484
# ----------   1442 remaining sequences to the next cycle
# ---------- new table with      276 representatives
# # comparing sequences from      46042  to      47912
# ----------   1437 remaining sequences to the next cycle
# ---------- new table with      235 representatives
# # comparing sequences from      46475  to      48309
# ----------   1416 remaining sequences to the next cycle
# ---------- new table with      247 representatives
# # comparing sequences from      46893  to      48693
# ----------   1392 remaining sequences to the next cycle
# ---------- new table with      234 representatives
# # comparing sequences from      47301  to      49067
# ----------   1355 remaining sequences to the next cycle
# ---------- new table with      241 representatives
# # comparing sequences from      47712  to      49443
# ----------   1327 remaining sequences to the next cycle
# ---------- new table with      246 representatives
# # comparing sequences from      48116  to      49814
# ----------   1293 remaining sequences to the next cycle
# ---------- new table with      241 representatives
# # comparing sequences from      48521  to      50185
# ----------   1254 remaining sequences to the next cycle
# ---------- new table with      213 representatives
# # comparing sequences from      48931  to      50561
# ----------   1216 remaining sequences to the next cycle
# ---------- new table with      234 representatives
# # comparing sequences from      49345  to      50940
# ----------   1240 remaining sequences to the next cycle
# ---------- new table with      211 representatives
# # comparing sequences from      49700  to      51266
# ..........    50000  finished      29615  clusters
# ----------   1213 remaining sequences to the next cycle
# ---------- new table with      204 representatives
# # comparing sequences from      50053  to      51589
# ----------   1145 remaining sequences to the next cycle
# ---------- new table with      217 representatives
# # comparing sequences from      50444  to      51948
# ----------   1126 remaining sequences to the next cycle
# ---------- new table with      208 representatives
# # comparing sequences from      50822  to      52294
# ----------   1118 remaining sequences to the next cycle
# ---------- new table with      219 representatives
# # comparing sequences from      51176  to      52619
# ----------   1043 remaining sequences to the next cycle
# ---------- new table with      226 representatives
# # comparing sequences from      51576  to      52985
# ----------   1040 remaining sequences to the next cycle
# ---------- new table with      217 representatives
# # comparing sequences from      51945  to      53324
# ----------    964 remaining sequences to the next cycle
# ---------- new table with      238 representatives
# # comparing sequences from      52360  to      53704
# ----------    997 remaining sequences to the next cycle
# ---------- new table with      178 representatives
# # comparing sequences from      52707  to      54022
# ----------    957 remaining sequences to the next cycle
# ---------- new table with      219 representatives
# # comparing sequences from      53065  to      54350
# ----------    927 remaining sequences to the next cycle
# ---------- new table with      191 representatives
# # comparing sequences from      53423  to      54678
# ----------    922 remaining sequences to the next cycle
# ---------- new table with      187 representatives
# # comparing sequences from      53756  to      54984
# ----------    900 remaining sequences to the next cycle
# ---------- new table with      204 representatives
# # comparing sequences from      54084  to      55284
# ----------    845 remaining sequences to the next cycle
# ---------- new table with      193 representatives
# # comparing sequences from      54439  to      55610
# ----------    875 remaining sequences to the next cycle
# ---------- new table with      173 representatives
# # comparing sequences from      54735  to      55881
# ----------    857 remaining sequences to the next cycle
# ---------- new table with      162 representatives
# # comparing sequences from      55024  to      56146
# ----------    875 remaining sequences to the next cycle
# ---------- new table with      139 representatives
# # comparing sequences from      55271  to      56372
# ----------    767 remaining sequences to the next cycle
# ---------- new table with      201 representatives
# # comparing sequences from      55605  to      56679
# ----------    760 remaining sequences to the next cycle
# ---------- new table with      185 representatives
# # comparing sequences from      55919  to      56966
# ----------    723 remaining sequences to the next cycle
# ---------- new table with      170 representatives
# # comparing sequences from      56243  to      57263
# ----------    741 remaining sequences to the next cycle
# ---------- new table with      143 representatives
# # comparing sequences from      56522  to      57519
# ----------    676 remaining sequences to the next cycle
# ---------- new table with      195 representatives
# # comparing sequences from      56843  to      57813
# ----------    710 remaining sequences to the next cycle
# ---------- new table with      159 representatives
# # comparing sequences from      57103  to      58052
# ----------    642 remaining sequences to the next cycle
# ---------- new table with      165 representatives
# # comparing sequences from      57410  to      58333
# ----------    644 remaining sequences to the next cycle
# ---------- new table with      149 representatives
# # comparing sequences from      57689  to      58589
# ----------    622 remaining sequences to the next cycle
# ---------- new table with      170 representatives
# # comparing sequences from      57967  to      58844
# ----------    629 remaining sequences to the next cycle
# ---------- new table with      148 representatives
# # comparing sequences from      58215  to      59071
# ----------    554 remaining sequences to the next cycle
# ---------- new table with      165 representatives
# # comparing sequences from      58517  to      59348
# ----------    577 remaining sequences to the next cycle
# ---------- new table with      145 representatives
# # comparing sequences from      58771  to      59581
# ----------    541 remaining sequences to the next cycle
# ---------- new table with      162 representatives
# # comparing sequences from      59040  to      59827
# ----------    520 remaining sequences to the next cycle
# ---------- new table with      141 representatives
# # comparing sequences from      59307  to      60072
# ----------    500 remaining sequences to the next cycle
# ---------- new table with      152 representatives
# # comparing sequences from      59572  to      60315
# ----------    461 remaining sequences to the next cycle
# ---------- new table with      149 representatives
# # comparing sequences from      59854  to      60573
# ..........    60000  finished      35319  clusters
# ----------    473 remaining sequences to the next cycle
# ---------- new table with      141 representatives
# # comparing sequences from      60100  to      60799
# ----------    456 remaining sequences to the next cycle
# ---------- new table with      149 representatives
# # comparing sequences from      60343  to      61022
# ----------    413 remaining sequences to the next cycle
# ---------- new table with      147 representatives
# # comparing sequences from      60609  to      61266
# ----------    434 remaining sequences to the next cycle
# ---------- new table with      131 representatives
# # comparing sequences from      60832  to      61470
# ----------    400 remaining sequences to the next cycle
# ---------- new table with      124 representatives
# # comparing sequences from      61070  to      61688
# ----------    425 remaining sequences to the next cycle
# ---------- new table with      110 representatives
# # comparing sequences from      61263  to      61865
# ----------    374 remaining sequences to the next cycle
# ---------- new table with      145 representatives
# # comparing sequences from      61491  to      62074
# ----------    386 remaining sequences to the next cycle
# ---------- new table with      100 representatives
# # comparing sequences from      61688  to      62255
# ----------    374 remaining sequences to the next cycle
# ---------- new table with      110 representatives
# # comparing sequences from      61881  to      62432
# ----------    347 remaining sequences to the next cycle
# ---------- new table with      130 representatives
# # comparing sequences from      62085  to      62619
# ----------    322 remaining sequences to the next cycle
# ---------- new table with      119 representatives
# # comparing sequences from      62297  to      62813
# ----------    339 remaining sequences to the next cycle
# ---------- new table with      104 representatives
# # comparing sequences from      62474  to      62975
# ----------    302 remaining sequences to the next cycle
# ---------- new table with      114 representatives
# # comparing sequences from      62673  to      63158
# ----------    292 remaining sequences to the next cycle
# ---------- new table with      100 representatives
# # comparing sequences from      62866  to      63334
# ----------    298 remaining sequences to the next cycle
# ---------- new table with      107 representatives
# # comparing sequences from      63036  to      63490
# ----------    264 remaining sequences to the next cycle
# ---------- new table with      103 representatives
# # comparing sequences from      63226  to      63664
# ----------    244 remaining sequences to the next cycle
# ---------- new table with      100 representatives
# # comparing sequences from      63420  to      63842
# ----------    230 remaining sequences to the next cycle
# ---------- new table with      100 representatives
# # comparing sequences from      63612  to      64018
# ----------    235 remaining sequences to the next cycle
# ---------- new table with      100 representatives
# # comparing sequences from      63783  to      64175
# ----------    217 remaining sequences to the next cycle
# ---------- new table with      100 representatives
# # comparing sequences from      63958  to      64335
# ----------    195 remaining sequences to the next cycle
# ---------- new table with      100 representatives
# # comparing sequences from      64140  to      64502
# ----------    198 remaining sequences to the next cycle
# ---------- new table with      100 representatives
# # comparing sequences from      64304  to      64653
# ----------    187 remaining sequences to the next cycle
# ---------- new table with      102 representatives
# # comparing sequences from      64466  to      64801
# ----------    143 remaining sequences to the next cycle
# ---------- new table with      100 representatives
# # comparing sequences from      64658  to      64977
# ----------    136 remaining sequences to the next cycle
# ---------- new table with      100 representatives
# # comparing sequences from      64841  to      65145
# ----------    132 remaining sequences to the next cycle
# ---------- new table with      100 representatives
# # comparing sequences from      65013  to      65303
# ----------    110 remaining sequences to the next cycle
# ---------- new table with      100 representatives
# # comparing sequences from      65193  to      65468
# ----------    107 remaining sequences to the next cycle
# ---------- new table with      100 representatives
# # comparing sequences from      65361  to      65622
# ----------     83 remaining sequences to the next cycle
# ---------- new table with      100 representatives
# # comparing sequences from      65539  to      65785
# ----------     60 remaining sequences to the next cycle
# ---------- new table with      100 representatives
# # comparing sequences from      65725  to      65955
# ----------     66 remaining sequences to the next cycle
# ---------- new table with      100 representatives
# # comparing sequences from      65889  to      66106
# ----------     29 remaining sequences to the next cycle
# ---------- new table with      100 representatives
# # comparing sequences from      66077  to      66278
# ----------     16 remaining sequences to the next cycle
# ---------- new table with      100 representatives
# # comparing sequences from      66262  to      66447
# ----------      4 remaining sequences to the next cycle
# ---------- new table with      100 representatives
# # comparing sequences from      66443  to      66613
# ................---------- new table with       98 representatives
# # comparing sequences from      66613  to      66769
# ....................---------- new table with       94 representatives
# # comparing sequences from      66769  to      66912
# .................---------- new table with       80 representatives
# # comparing sequences from      66912  to      67043
# ....................---------- new table with       83 representatives
# # comparing sequences from      67043  to      67163
# ...............---------- new table with       69 representatives
# # comparing sequences from      67163  to      67273
# ..................---------- new table with       64 representatives
# # comparing sequences from      67273  to      67374
# ................---------- new table with       54 representatives
# # comparing sequences from      67374  to      67467
# ................---------- new table with       51 representatives
# # comparing sequences from      67467  to      67552
# ................---------- new table with       50 representatives
# # comparing sequences from      67552  to      68493
# ..................---------- new table with      589 representatives
#
#     68493  finished      40193  clusters
#
# Approximated maximum memory consumption: 408M
# writing new database
# writing clustering information
# program completed !
#
# Total CPU time 63.64

# %%
## Removing sequences longer than 780 residues (since my GPU cant handle them)
## We also filter sequences with Non standard residues
import math
NON_STANDARD_AMINO = ["B", "U", "Z", "X"]

from Bio import SeqIO
df = {"id":[], "TM": [], "seq":[], "Data_set":[]}
for rec in SeqIO.parse("../data/all_tms_noredun.fasta", "fasta"):
    df["id"].append(rec.id)
    df["TM"].append(math.floor(float(rec.description.split()[-1])))
    df["Data_set"].append(rec.description.split()[-2])
    df["seq"].append(str(rec.seq))
df = pd.DataFrame(df)
with open("../data/all_tms_noredun_780.fasta", "w") as f:
    for row in df.iterrows():
        seq = row[1]["seq"]
        if len(seq) > 780:
            print(f"Removing {row[1]['id']} due to length")
            continue
        if any(amino in seq for amino in NON_STANDARD_AMINO):
            print(f"Removing {row[1]['id']} due to non standard res")
            continue
        id_ = row[1]["id"]
        seq = row[1]["seq"]
        TM  = row[1]["TM"]
        da  = row[1]["Data_set"]
        
        f.write(f">{id_} {da} {TM}\n{seq}\n")
        
if any(amino in sequence for amino in NON_STANDARD_AMINO):
    raise ValueError (f"Sequences can not contain non standard amino acids")
# Out:
# Removing A0A061ACR1 due to length
# Removing A0A061AD29 due to length
# Removing A0A087WP63 due to length
# Removing A0A087WPH5 due to non standard res
# Removing A0A087WPL5 due to length
# Removing A0A087WPR9 due to non standard res
# Removing A0A087WPX0 due to length
# Removing A0A087WQ86 due to length
# Removing A0A087WR24 due to length
# Removing A0A087WR75 due to length
# Removing A0A087WRE5 due to non standard res
# Removing A0A087WRE7 due to non standard res
# Removing A0A087WRM0 due to non standard res
# Removing A0A087WRV0 due to non standard res
# Removing A0A087WS03 due to length
# Removing A0A0A0MPG3 due to non standard res
# Removing A0A0A0MQ73 due to length
# Removing A0A0A0MQ79 due to length
# Removing A0A0A0MQ98 due to length
# Removing A0A0A0MQA5 due to non standard res
# Removing A0A0A0MQD1 due to length
# Removing A0A0A0MQE5 due to length
# Removing A0A0A6YVS2 due to non standard res
# Removing A0A0A6YW28 due to length
# Removing A0A0A6YWG7 due to length
# Removing A0A0A6YX25 due to non standard res
# Removing A0A0A6YX40 due to length
# Removing A0A0A6YXG1 due to length
# Removing A0A0A6YXL6 due to length
# Removing A0A0A6YY67 due to length
# Removing A0A0G2JFF1 due to non standard res
# Removing A0A0G2JFH9 due to length
# Removing A0A0G2JFJ6 due to length
# Removing A0A0G2JFQ4 due to length
# Removing A0A0G2JGL8 due to length
# Removing A0A0G2JGX4 due to length
# Removing A0A0H2UKB8 due to length
# Removing A0A0J9YTU3 due to length
# Removing A0A0J9YU61 due to length
# Removing A0A0J9YUT8 due to length
# Removing A0A0J9YV01 due to length
# Removing A0A0K3AS01 due to length
# Removing A0A0K3AS90 due to length
# Removing A0A0K3ASH9 due to length
# Removing A0A0K3AUF2 due to length
# Removing A0A0K3AUZ7 due to length
# Removing A0A0K3AYH6 due to length
# Removing A0A0N4SUM2 due to non standard res
# Removing A0A0N4SUS4 due to length
# Removing A0A0N4SV29 due to length
# Removing A0A0N4SV80 due to length
# Removing A0A0N4SVL0 due to length
# Removing A0A0N4SW73 due to length
# Removing A0A0N4SW93 due to length
# Removing A0A0N4SWD0 due to non standard res
# Removing A0A0N5E9G7 due to length
# Removing A0A0R4IGL6 due to length
# Removing A0A0R4IU05 due to length
# Removing A0A0R4IU19 due to length
# Removing A0A0R4IVD0 due to length
# Removing A0A0R4IZZ6 due to length
# Removing A0A0R4J007 due to length
# Removing A0A0R4J015 due to length
# Removing A0A0R4J036 due to length
# Removing A0A0R4J060 due to length
# Removing A0A0R4J092 due to length
# Removing A0A0R4J0D3 due to length
# Removing A0A0R4J0E4 due to length
# Removing A0A0R4J0F6 due to length
# Removing A0A0R4J0H7 due to length
# Removing A0A0R4J0H8 due to length
# Removing A0A0R4J0I4 due to length
# Removing A0A0R4J0I9 due to length
# Removing A0A0R4J0M9 due to length
# Removing A0A0R4J0S4 due to length
# Removing A0A0R4J0V5 due to length
# Removing A0A0R4J107 due to non standard res
# Removing A0A0R4J150 due to length
# Removing A0A0R4J170 due to length
# Removing A0A0R4J172 due to length
# Removing A0A0R4J1F8 due to length
# Removing A0A0R4J1I6 due to length
# Removing A0A0R4J1K4 due to length
# Removing A0A0R4J254 due to length
# Removing A0A0R4J260 due to length
# Removing A0A0T7CIX3 due to length
# Removing A0A0U1RML6 due to length
# Removing A0A0U1RNK7 due to length
# Removing A0A0U1RNN5 due to non standard res
# Removing A0A0U1RPG9 due to non standard res
# Removing A0A0U1RPL0 due to length
# Removing A0A0U1RPM2 due to length
# Removing A0A131MAZ4 due to length
# Removing A0A131MCD3 due to length
# Removing A0A131MCR8 due to length
# Removing A0A131MD37 due to length
# Removing A0A140LHU0 due to length
# Removing A0A140LI54 due to length
# Removing A0A140LIW3 due to length
# Removing A0A171EBL2 due to length
# Removing A0A1L1QZU5 due to length
# Removing A0A9S2 due to length
# Removing A1A4T4 due to length
# Removing A1BN54 due to length
# Removing A1L2Z0 due to length
# Removing A1Z7T0 due to length
# Removing A1Z8P9 due to length
# Removing A1Z9E2 due to length
# Removing A1Z9P3 due to length
# Removing A1ZA47 due to length
# Removing A1ZA92 due to length
# Removing A1ZAB5 due to length
# Removing A1ZAJ2 due to length
# Removing A1ZAU8 due to length
# Removing A1ZBE8 due to length
# Removing A1ZBW7 due to length
# Removing A2A432 due to length
# Removing A2A468 due to length
# Removing A2A4P0 due to length
# Removing A2A5R2 due to length
# Removing A2A5Y4 due to length
# Removing A2A6Q5 due to length
# Removing A2A791 due to length
# Removing A2A7A7 due to length
# Removing A2A7F6 due to length
# Removing A2A7S8 due to length
# Removing A2A8L5 due to length
# Removing A2A8R7 due to length
# Removing A2A8V9 due to length
# Removing A2AAY5 due to length
# Removing A2AB59 due to length
# Removing A2ABV5 due to length
# Removing A2ACV6 due to length
# Removing A2ADE0 due to length
# Removing A2AE27 due to length
# Removing A2AF47 due to length
# Removing A2AFF6 due to length
# Removing A2AFQ0 due to length
# Removing A2AFQ9 due to length
# Removing A2AFY7 due to length
# Removing A2AG36 due to length
# Removing A2AG68 due to length
# Removing A2AGH8 due to length
# Removing A2AGT5 due to length
# Removing A2AHJ7 due to length
# Removing A2AI52 due to length
# Removing A2AJ88 due to length
# Removing A2AJT5 due to length
# Removing A2AKG8 due to length
# Removing A2AKI5 due to length
# Removing A2AN08 due to length
# Removing A2AN61 due to length
# Removing A2ANY6 due to length
# Removing A2AP88 due to length
# Removing A2API3 due to length
# Removing A2APY6 due to length
# Removing A2AQA7 due to length
# Removing A2AQJ8 due to length
# Removing A2AS70 due to length
# Removing A2ASQ1 due to length
# Removing A2ASS6 due to length
# Removing A2AT37 due to length
# Removing A2ATU0 due to length
# Removing A2AUY4 due to length
# Removing A2AVJ7 due to length
# Removing A2AWA9 due to length
# Removing A2AWF8 due to length
# Removing A2AWP8 due to length
# Removing A2CE51 due to length
# Removing A2CG63 due to length
# Removing A2CG76 due to length
# Removing A2RSJ4 due to length
# Removing A2RSY1 due to length
# Removing A3KG93 due to length
# Removing A3KGB4 due to length
# Removing A3KGU5 due to length
# Removing A4GSN8 due to length
# Removing A5D6P3 due to length
# Removing A5HW96 due to length
# Removing A5JYU5 due to length
# Removing A5JYW9 due to length
# Removing A5Z2T6 due to length
# Removing A6H5Y3 due to length
# Removing A6H619 due to length
# Removing A6H6A9 due to length
# Removing A6H8H2 due to length
# Removing A6MDD3 due to length
# Removing A6PWC3 due to length
# Removing A6PWP8 due to length
# Removing A6X8Z5 due to length
# Removing A6X935 due to length
# Removing A7LPD8 due to length
# Removing A8C756 due to length
# Removing A8DYE2 due to length
# Removing A8DYP0 due to length
# Removing A8JUV0 due to length
# Removing A8R7K9 due to length
# Removing A9JR75 due to length
# Removing A9JRE6 due to length
# Removing B0F481 due to length
# Removing B0F9L4 due to length
# Removing B0M0N9 due to length
# Removing B0QZF8 due to length
# Removing B0QZL5 due to length
# Removing B0V2P6 due to length
# Removing B1ARD6 due to length
# Removing B1ASP2 due to length
# Removing B1AT03 due to length
# Removing B1ATS5 due to length
# Removing B1AVH7 due to length
# Removing B1AVP1 due to length
# Removing B1AVY7 due to length
# Removing B1AY10 due to length
# Removing B1AYU7 due to length
# Removing B1AZ81 due to length
# Removing B1AZF9 due to length
# Removing B1AZI6 due to length
# Removing B1AZP2 due to length
# Removing B2FDA8 due to length
# Removing B2KF50 due to length
# Removing B2RQ57 due to length
# Removing B2RQ71 due to length
# Removing B2RQC6 due to length
# Removing B2RQG2 due to length
# Removing B2RSU7 due to length
# Removing B2RT41 due to length
# Removing B2RUJ2 due to length
# Removing B2RUR3 due to length
# Removing B2RUR8 due to length
# Removing B2RWS6 due to length
# Removing B2RX66 due to length
# Removing B2RXC1 due to length
# Removing B2RXC2 due to length
# Removing B2RXC6 due to length
# Removing B2RXR6 due to length
# Removing B2RXS4 due to length
# Removing B2RXW8 due to length
# Removing B2RXX9 due to length
# Removing B2RY04 due to length
# Removing B3CJ34 due to length
# Removing B3H5K9 due to length
# Removing B4HMY3 due to length
# Removing B4HN85 due to length
# Removing B4HR78 due to length
# Removing B4HS00 due to length
# Removing B4IMI7 due to length
# Removing B4NXB9 due to length
# Removing B4P624 due to length
# Removing B4Q034 due to length
# Removing B4QCR6 due to length
# Removing B5BM28 due to length
# Removing B6VQ62 due to length
# Removing B6YY24 due to length
# Removing B7FAS0 due to length
# Removing B7ZCJ0 due to length
# Removing B7ZNG0 due to length
# Removing B7ZNP0 due to length
# Removing B7ZNS2 due to length
# Removing B7ZP47 due to length
# Removing B7ZWL1 due to length
# Removing B8JK39 due to length
# Removing B9DFX7 due to length
# Removing B9EHN0 due to length
# Removing B9EJ54 due to length
# Removing B9EJ80 due to length
# Removing B9EJR8 due to length
# Removing C0LGG8 due to length
# Removing C0LGG9 due to length
# Removing C0LGQ9 due to length
# Removing C0SP86 due to length
# Removing C1P633 due to length
# Removing C1P641 due to length
# Removing D0IMZ5 due to length
# Removing D0Z5N4 due to length
# Removing D1GJ56 due to length
# Removing D3DEL8 due to length
# Removing D3YTT9 due to length
# Removing D3YTV3 due to length
# Removing D3YUS5 due to length
# Removing D3YUW8 due to length
# Removing D3YW20 due to length
# Removing D3YWD3 due to length
# Removing D3YWS8 due to length
# Removing D3YWX2 due to length
# Removing D3YZ62 due to length
# Removing D3YZC7 due to length
# Removing D3YZW1 due to length
# Removing D3Z0K6 due to length
# Removing D3Z0M9 due to length
# Removing D3Z0R8 due to length
# Removing D3Z197 due to length
# Removing D3Z2E7 due to length
# Removing D3Z2Q2 due to length
# Removing D3Z2R5 due to non standard res
# Removing D3Z4C0 due to length
# Removing D3Z4E6 due to length
# Removing D3Z4I0 due to length
# Removing D3Z5I1 due to length
# Removing D3Z5I9 due to length
# Removing D3Z5N5 due to length
# Removing D3Z656 due to length
# Removing D3Z6B9 due to length
# Removing D3Z7H8 due to length
# Removing D6R8W9 due to length
# Removing D6RET6 due to length
# Removing D6RHM2 due to length
# Removing E0CXE7 due to length
# Removing E1JH25 due to length
# Removing E2JL04 due to length
# Removing E7EYE1 due to length
# Removing E7F2L1 due to length
# Removing E7F9F6 due to length
# Removing E7FD56 due to length
# Removing E7FM69 due to length
# Removing E9PU96 due to length
# Removing E9PUE7 due to length
# Removing E9PUF7 due to length
# Removing E9PUM4 due to length
# Removing E9PUQ9 due to length
# Removing E9PUV9 due to length
# Removing E9PUW7 due to length
# Removing E9PV24 due to length
# Removing E9PV41 due to length
# Removing E9PV45 due to length
# Removing E9PVA8 due to length
# Removing E9PVC5 due to length
# Removing E9PVD3 due to length
# Removing E9PVP1 due to length
# Removing E9PVX6 due to length
# Removing E9PVY8 due to length
# Removing E9PVZ8 due to length
# Removing E9PWB1 due to length
# Removing E9PWD9 due to length
# Removing E9PWG6 due to length
# Removing E9PX30 due to length
# Removing E9PX53 due to length
# Removing E9PX59 due to length
# Removing E9PXI0 due to length
# Removing E9PXU2 due to length
# Removing E9PYG6 due to length
# Removing E9PYH6 due to length
# Removing E9PYJ6 due to length
# Removing E9PYL2 due to length
# Removing E9PYT0 due to length
# Removing E9PZA7 due to length
# Removing E9PZJ8 due to length
# Removing E9PZM4 due to length
# Removing E9PZY1 due to length
# Removing E9PZY8 due to length
# Removing E9Q0A3 due to length
# Removing E9Q0A7 due to length
# Removing E9Q0N0 due to length
# Removing E9Q0Y4 due to length
# Removing E9Q1K0 due to length
# Removing E9Q1L5 due to length
# Removing E9Q1M6 due to length
# Removing E9Q1T9 due to length
# Removing E9Q1W7 due to length
# Removing E9Q286 due to length
# Removing E9Q2A6 due to length
# Removing E9Q2B2 due to length
# Removing E9Q2H1 due to length
# Removing E9Q2I1 due to length
# Removing E9Q2I4 due to length
# Removing E9Q2M9 due to length
# Removing E9Q2X6 due to length
# Removing E9Q309 due to length
# Removing E9Q394 due to length
# Removing E9Q3G7 due to length
# Removing E9Q3L2 due to length
# Removing E9Q3P4 due to length
# Removing E9Q3X0 due to length
# Removing E9Q3X4 due to length
# Removing E9Q411 due to length
# Removing E9Q414 due to length
# Removing E9Q467 due to length
# Removing E9Q481 due to length
# Removing E9Q4K7 due to length
# Removing E9Q4M2 due to length
# Removing E9Q4S1 due to length
# Removing E9Q4Z2 due to length
# Removing E9Q512 due to length
# Removing E9Q586 due to length
# Removing E9Q5A8 due to length
# Removing E9Q5F9 due to length
# Removing E9Q5G3 due to length
# Removing E9Q634 due to length
# Removing E9Q640 due to length
# Removing E9Q6A7 due to length
# Removing E9Q6G4 due to length
# Removing E9Q6L0 due to length
# Removing E9Q6P5 due to length
# Removing E9Q6R4 due to length
# Removing E9Q6R7 due to length
# Removing E9Q704 due to length
# Removing E9Q723 due to length
# Removing E9Q784 due to length
# Removing E9Q7C3 due to length
# Removing E9Q7E9 due to length
# Removing E9Q7G0 due to length
# Removing E9Q7L1 due to length
# Removing E9Q7L3 due to length
# Removing E9Q7P6 due to length
# Removing E9Q852 due to length
# Removing E9Q8A3 due to length
# Removing E9Q8I7 due to length
# Removing E9Q8K8 due to length
# Removing E9Q8L9 due to length
# Removing E9Q8N5 due to length
# Removing E9Q8Z5 due to length
# Removing E9Q9B7 due to length
# Removing E9Q9F7 due to length
# Removing E9Q9M5 due to length
# Removing E9Q9Q2 due to length
# Removing E9Q9T4 due to length
# Removing E9Q9V3 due to length
# Removing E9Q9X1 due to length
# Removing E9QAE3 due to length
# Removing E9QAI5 due to length
# Removing E9QAJ9 due to length
# Removing E9QAM5 due to length
# Removing E9QAP7 due to length
# Removing E9QAQ7 due to length
# Removing E9QAS4 due to length
# Removing E9QAT4 due to length
# Removing E9QB02 due to length
# Removing E9QFR8 due to length
# Removing E9QK83 due to length
# Removing E9QK89 due to length
# Removing E9QKE4 due to length
# Removing E9QKE9 due to length
# Removing E9QKG6 due to length
# Removing E9QKK8 due to length
# Removing E9QKZ2 due to length
# Removing E9QL65 due to length
# Removing E9QLA5 due to length
# Removing E9QLK3 due to length
# Removing E9QLL2 due to length
# Removing E9QM38 due to length
# Removing E9QM77 due to length
# Removing E9QME5 due to length
# Removing E9QMX4 due to length
# Removing E9QMX7 due to length
# Removing E9QN31 due to length
# Removing E9QNE9 due to length
# Removing E9QP59 due to length
# Removing E9QP84 due to length
# Removing E9QP99 due to length
# Removing E9QPI5 due to length
# Removing E9QQ10 due to length
# Removing E9QQ30 due to length
# Removing F1Q611 due to length
# Removing F1QJM7 due to non standard res
# Removing F1QSY7 due to length
# Removing F1QV21 due to length
# Removing F1R4W2 due to non standard res
# Removing F2Z3U3 due to length
# Removing F2Z470 due to length
# Removing F2Z4A9 due to length
# Removing F3Y5P4 due to length
# Removing F4HNU6 due to length
# Removing F4HTM3 due to length
# Removing F4HXV6 due to length
# Removing F4I116 due to length
# Removing F4I6M1 due to length
# Removing F4I893 due to length
# Removing F4IAG2 due to length
# Removing F4IG73 due to length
# Removing F4IGA5 due to length
# Removing F4IIM1 due to length
# Removing F4IIS5 due to length
# Removing F4IRR2 due to length
# Removing F4IUX6 due to length
# Removing F4IXW2 due to length
# Removing F4IYF8 due to length
# Removing F4IYM4 due to length
# Removing F4IZR5 due to length
# Removing F4J1H7 due to length
# Removing F4J5S1 due to length
# Removing F4J738 due to length
# Removing F4J8C6 due to length
# Removing F4J8D3 due to length
# Removing F4J8L3 due to length
# Removing F4JCU0 due to length
# Removing F4JFN3 due to length
# Removing F4JHH5 due to length
# Removing F4JKH6 due to length
# Removing F4JLM5 due to length
# Removing F4JMJ1 due to length
# Removing F4JVN6 due to length
# Removing F4K2E9 due to length
# Removing F4K487 due to length
# Removing F4KAB8 due to length
# Removing F4KE63 due to length
# Removing F4KEY9 due to length
# Removing F6PWU6 due to non standard res
# Removing F6QKK2 due to non standard res
# Removing F6RDM4 due to non standard res
# Removing F6RK07 due to length
# Removing F6S5I0 due to length
# Removing F6SBR5 due to length
# Removing F6SGV3 due to non standard res
# Removing F6SMJ7 due to non standard res
# Removing F6SPQ1 due to non standard res
# Removing F6T2X5 due to length
# Removing F6T9H9 due to non standard res
# Removing F6TLV3 due to length
# Removing F6TN13 due to non standard res
# Removing F6TVP2 due to non standard res
# Removing F6TWX0 due to non standard res
# Removing F6U6E8 due to non standard res
# Removing F6U775 due to non standard res
# Removing F6UDR6 due to non standard res
# Removing F6UK66 due to non standard res
# Removing F6UTB8 due to non standard res
# Removing F6UV46 due to non standard res
# Removing F6V059 due to non standard res
# Removing F6V6T4 due to non standard res
# Removing F6VAL0 due to non standard res
# Removing F6WMJ3 due to length
# Removing F6XVP7 due to length
# Removing F6XX07 due to non standard res
# Removing F6XYC5 due to non standard res
# Removing F6Y765 due to non standard res
# Removing F6YRW4 due to length
# Removing F6YZU5 due to length
# Removing F6ZBL2 due to non standard res
# Removing F6ZBR8 due to length
# Removing F7ACR9 due to length
# Removing F7AL76 due to length
# Removing F7BFL8 due to non standard res
# Removing F7BX26 due to non standard res
# Removing F7CB97 due to length
# Removing F7CCJ3 due to non standard res
# Removing F7CK55 due to length
# Removing F7CVW0 due to length
# Removing F8VPK0 due to length
# Removing F8VPK6 due to length
# Removing F8VPN4 due to length
# Removing F8VPQ2 due to length
# Removing F8VPR5 due to length
# Removing F8VPT6 due to length
# Removing F8VPV0 due to length
# Removing F8VPX1 due to length
# Removing F8VPZ9 due to length
# Removing F8VQ29 due to length
# Removing F8VQ87 due to length
# Removing F8VQ93 due to length
# Removing F8VQC7 due to length
# Removing F8VQC9 due to length
# Removing F8VQE9 due to length
# Removing F8VQJ3 due to length
# Removing F8VQK5 due to length
# Removing F8W428 due to length
# Removing F8WGW3 due to length
# Removing F8WH20 due to length
# Removing F8WHL2 due to length
# Removing F8WHM5 due to length
# Removing F8WHT3 due to length
# Removing F8WHU5 due to length
# Removing F8WHU7 due to length
# Removing F8WI56 due to length
# Removing F8WIG5 due to length
# Removing F8WIU7 due to length
# Removing F8WJ05 due to length
# Removing F8WJ93 due to length
# Removing F8WJA0 due to length
# Removing F8WJB0 due to length
# Removing G0ZKW2 due to length
# Removing G3MU40 due to length
# Removing G3MU81 due to length
# Removing G3UVV4 due to length
# Removing G3UW82 due to length
# Removing G3UW90 due to length
# Removing G3UWZ0 due to length
# Removing G3UXH4 due to length
# Removing G3UYD0 due to length
# Removing G3UYG6 due to length
# Removing G3UYJ7 due to non standard res
# Removing G3X8Q0 due to length
# Removing G3X8U8 due to length
# Removing G3X8X0 due to length
# Removing G3X8X7 due to length
# Removing G3X8Y3 due to length
# Removing G3X914 due to length
# Removing G3X922 due to length
# Removing G3X928 due to length
# Removing G3X956 due to length
# Removing G3X963 due to length
# Removing G3X972 due to length
# Removing G3X9A3 due to length
# Removing G3X9B1 due to length
# Removing G3X9H5 due to length
# Removing G3X9J0 due to length
# Removing G3X9J4 due to length
# Removing G3X9K3 due to length
# Removing G3X9Q3 due to length
# Removing G3X9Y5 due to length
# Removing G3X9Z4 due to length
# Removing G3XA09 due to length
# Removing G4SLH0 due to length
# Removing G5E829 due to length
# Removing G5E866 due to length
# Removing G5E870 due to length
# Removing G5E896 due to length
# Removing G5E8C4 due to length
# Removing G5E8I8 due to length
# Removing G5E8J3 due to length
# Removing G5E8N3 due to length
# Removing G5E8R3 due to length
# Removing G5E8R4 due to length
# Removing G5E8S0 due to length
# Removing G5E924 due to non standard res
# Removing G5EBH2 due to length
# Removing G5EBH3 due to length
# Removing G5EBK0 due to length
# Removing G5EBQ9 due to length
# Removing G5EBW2 due to length
# Removing G5EBZ1 due to length
# Removing G5EBZ4 due to length
# Removing G5EC05 due to length
# Removing G5EC23 due to length
# Removing G5EC56 due to length
# Removing G5EC94 due to length
# Removing G5EC95 due to length
# Removing G5ECC7 due to length
# Removing G5ECE3 due to length
# Removing G5ECG7 due to length
# Removing G5ECK5 due to length
# Removing G5ECL2 due to length
# Removing G5ECL4 due to length
# Removing G5ECV9 due to length
# Removing G5ECY0 due to length
# Removing G5ED16 due to length
# Removing G5ED20 due to length
# Removing G5ED21 due to length
# Removing G5ED25 due to non standard res
# Removing G5ED27 due to length
# Removing G5ED39 due to length
# Removing G5ED41 due to length
# Removing G5ED87 due to length
# Removing G5ED99 due to length
# Removing G5EDG2 due to length
# Removing G5EDJ6 due to length
# Removing G5EDS2 due to length
# Removing G5EDT1 due to length
# Removing G5EDT8 due to length
# Removing G5EDW5 due to length
# Removing G5EE16 due to length
# Removing G5EE66 due to length
# Removing G5EE72 due to length
# Removing G5EEA3 due to length
# Removing G5EEB8 due to length
# Removing G5EEM5 due to length
# Removing G5EEP7 due to length
# Removing G5EEY5 due to length
# Removing G5EF07 due to length
# Removing G5EF28 due to length
# Removing G5EF53 due to length
# Removing G5EF87 due to length
# Removing G5EF96 due to length
# Removing G5EFD5 due to length
# Removing G5EFH7 due to length
# Removing G5EFJ0 due to length
# Removing G5EFJ7 due to length
# Removing G5EFJ8 due to length
# Removing G5EFM4 due to length
# Removing G5EFX2 due to length
# Removing G5EFY6 due to length
# Removing G5EG17 due to length
# Removing G5EG57 due to length
# Removing G5EG62 due to length
# Removing G5EG68 due to length
# Removing G5EG78 due to length
# Removing G5EGH4 due to length
# Removing G5EGI8 due to length
# Removing G5EGK1 due to length
# Removing G5EGL7 due to length
# Removing G5EGM3 due to length
# Removing G5EGQ8 due to length
# Removing G5EGS5 due to length
# Removing G5EGT7 due to length
# Removing G8JL73 due to non standard res
# Removing H1ZUX1 due to length
# Removing H2KY88 due to length
# Removing H2KYB2 due to length
# Removing H2KYN6 due to length
# Removing H2KYR2 due to length
# Removing H2KYS8 due to length
# Removing H2KZ18 due to length
# Removing H2KZD5 due to length
# Removing H2KZV4 due to length
# Removing H2KZV7 due to length
# Removing H2L041 due to length
# Removing H2L043 due to length
# Removing H2L055 due to length
# Removing H2L0N9 due to length
# Removing H2L265 due to length
# Removing H2L2F4 due to length
# Removing H3BIW0 due to length
# Removing H3BJ12 due to non standard res
# Removing H3BJH7 due to length
# Removing H3BK24 due to length
# Removing H3BK65 due to length
# Removing H3BKD4 due to length
# Removing H3BL37 due to length
# Removing H3BLS0 due to length
# Removing H7BWY4 due to length
# Removing H7BWZ9 due to length
# Removing H7BX01 due to length
# Removing H7BX26 due to length
# Removing H7BX50 due to length
# Removing H7BX64 due to length
# Removing H9KV15 due to length
# Removing I1E4X4 due to length
# Removing I1XUS8 due to length
# Removing I3ITN9 due to length
# Removing I3RSH5 due to length
# Removing I7J4D2 due to length
# Removing J7SA49 due to length
# Removing K3W4L0 due to length
# Removing K3W4P2 due to length
# Removing K3W4R2 due to length
# Removing K4DI77 due to length
# Removing K8ERU3 due to length
# Removing K8ESF0 due to length
# Removing K8ESI6 due to length
# Removing K8ESK4 due to length
# Removing K8F7V7 due to length
# Removing K8F804 due to length
# Removing L0CL36 due to length
# Removing L8E6W9 due to length
# Removing M0QW74 due to length
# Removing M9MSG8 due to length
# Removing M9NEY8 due to length
# Removing N1NTN5 due to length
# Removing N1NVC2 due to length
# Removing O01510 due to length
# Removing O01541 due to length
# Removing O01590 due to length
# Removing O01763 due to length
# Removing O01768 due to length
# Removing O01789 due to length
# Removing O01808 due to length
# Removing O01837 due to length
# Removing O01864 due to length
# Removing O01893 due to length
# Removing O01900 due to length
# Removing O01905 due to length
# Removing O02193 due to length
# Removing O02252 due to length
# Removing O02328 due to length
# Removing O02626 due to length
# Removing O04379 due to length
# Removing O04539 due to length
# Removing O06714 due to length
# Removing O08336 due to length
# Removing O08455 due to length
# Removing O08528 due to length
# Removing O08532 due to length
# Removing O08601 due to length
# Removing O08638 due to length
# Removing O08715 due to length
# Removing O08759 due to length
# Removing O08788 due to length
# Removing O08810 due to length
# Removing O09053 due to length
# Removing O09126 due to length
# Removing O16637 due to length
# Removing O16928 due to length
# Removing O16929 due to length
# Removing O17003 due to length
# Removing O17323 due to length
# Removing O17352 due to length
# Removing O17403 due to length
# Removing O17468 due to length
# Removing O17566 due to length
# Removing O17732 due to length
# Removing O17772 due to length
# Removing O17944 due to length
# Removing O17966 due to length
# Removing O18191 due to length
# Removing O18215 due to length
# Removing O18388 due to length
# Removing O18475 due to length
# Removing O22193 due to length
# Removing O22224 due to length
# Removing O22476 due to length
# Removing O22941 due to length
# Removing O23087 due to length
# Removing O23404 due to length
# Removing O23461 due to length
# Removing O23617 due to length
# Removing O23647 due to length
# Removing O31501 due to length
# Removing O31504 due to length
# Removing O31530 due to length
# Removing O31782 due to length
# Removing O31784 due to length
# Removing O32044 due to length
# Removing O32101 due to length
# Removing O32178 due to length
# Removing O32220 due to length
# Removing O34309 due to length
# Removing O34526 due to length
# Removing O34623 due to length
# Removing O34720 due to length
# Removing O34784 due to length
# Removing O34796 due to length
# Removing O34863 due to length
# Removing O34996 due to length
# Removing O35126 due to length
# Removing O35134 due to length
# Removing O35218 due to length
# Removing O35286 due to length
# Removing O35375 due to length
# Removing O35382 due to length
# Removing O35551 due to length
# Removing O35601 due to length
# Removing O35604 due to length
# Removing O35607 due to length
# Removing O35643 due to length
# Removing O35711 due to length
# Removing O35954 due to length
# Removing O44386 due to length
# Removing O44503 due to length
# Removing O44518 due to length
# Removing O44565 due to length
# Removing O44952 due to length
# Removing O44985 due to length
# Removing O45244 due to length
# Removing O45380 due to length
# Removing O45398 due to length
# Removing O45569 due to length
# Removing O46015 due to length
# Removing O46037 due to length
# Removing O48844 due to length
# Removing O48847 due to length
# Removing O48946 due to length
# Removing O48963 due to length
# Removing O49160 due to length
# Removing O54774 due to length
# Removing O54782 due to length
# Removing O54824 due to length
# Removing O54890 due to length
# Removing O54988 due to length
# Removing O55029 due to length
# Removing O55098 due to length
# Removing O55143 due to length
# Removing O55201 due to length
# Removing O61199 due to length
# Removing O61208 due to length
# Removing O61307 due to length
# Removing O61528 due to length
# Removing O61794 due to length
# Removing O61931 due to length
# Removing O62178 due to length
# Removing O62219 due to length
# Removing O62332 due to length
# Removing O62334 due to length
# Removing O62348 due to length
# Removing O62431 due to length
# Removing O62477 due to length
# Removing O62621 due to length
# Removing O64793 due to length
# Removing O64827 due to length
# Removing O65272 due to length
# Removing O65570 due to length
# Removing O70318 due to length
# Removing O70325 due to non standard res
# Removing O70362 due to length
# Removing O70372 due to length
# Removing O70481 due to length
# Removing O70494 due to length
# Removing O70589 due to length
# Removing O76373 due to length
# Removing O76512 due to length
# Removing O77086 due to length
# Removing O80452 due to length
# Removing O80988 due to length
# Removing O81283 due to length
# Removing O81644 due to length
# Removing O81645 due to length
# Removing O81742 due to length
# Removing O81852 due to length
# Removing O82491 due to length
# Removing O88343 due to length
# Removing O88502 due to length
# Removing O88508 due to length
# Removing O88512 due to length
# Removing O88532 due to length
# Removing O88783 due to length
# Removing O88839 due to length
# Removing O89001 due to length
# Removing O89026 due to length
# Removing O96433 due to length
# Removing O96651 due to length
# Removing O96838 due to length
# Removing O97159 due to length
# Removing O97394 due to length
# Removing P00490 due to length
# Removing P00522 due to length
# Removing P00561 due to length
# Removing P00562 due to length
# Removing P00582 due to length
# Removing P00815 due to length
# Removing P00864 due to length
# Removing P00956 due to length
# Removing P00957 due to length
# Removing P00967 due to length
# Removing P00968 due to length
# Removing P01027 due to length
# Removing P01029 due to length
# Removing P02463 due to length
# Removing P02918 due to length
# Removing P02919 due to length
# Removing P03965 due to length
# Removing P04050 due to length
# Removing P04051 due to length
# Removing P04052 due to length
# Removing P04146 due to length
# Removing P04825 due to length
# Removing P04919 due to length
# Removing P05030 due to length
# Removing P05374 due to length
# Removing P05458 due to length
# Removing P05653 due to length
# Removing P05990 due to length
# Removing P06102 due to length
# Removing P06105 due to length
# Removing P06612 due to length
# Removing P06684 due to length
# Removing P06738 due to length
# Removing P06909 due to length
# Removing P07118 due to length
# Removing P07149 due to length
# Removing P07244 due to length
# Removing P07245 due to length
# Removing P07248 due to length
# Removing P07259 due to length
# Removing P07395 due to length
# Removing P07648 due to length
# Removing P07702 due to length
# Removing P07742 due to length
# Removing P07806 due to length
# Removing P07813 due to length
# Removing P08032 due to length
# Removing P08111 due to length
# Removing P08113 due to length
# Removing P08120 due to length
# Removing P08201 due to length
# Removing P08394 due to length
# Removing P08518 due to length
# Removing P08566 due to length
# Removing P08953 due to length
# Removing P08956 due to length
# Removing P08970 due to length
# Removing P09152 due to length
# Removing P09208 due to length
# Removing P09339 due to length
# Removing P09436 due to length
# Removing P09440 due to length
# Removing P09470 due to length
# Removing P09546 due to length
# Removing P09581 due to length
# Removing P09803 due to length
# Removing P09831 due to length
# Removing P09880 due to length
# Removing P0A698 due to length
# Removing P0A705 due to length
# Removing P0A7A7 due to length
# Removing P0A8T7 due to length
# Removing P0A8V2 due to length
# Removing P0A940 due to length
# Removing P0A9M0 due to length
# Removing P0A9Q7 due to length
# Removing P0ABB8 due to length
# Removing P0AC86 due to length
# Removing P0AEC5 due to length
# Removing P0AES4 due to length
# Removing P0AES6 due to length
# Removing P0AFG3 due to length
# Removing P0AFG8 due to length
# Removing P0C2J5 due to length
# Removing P0CK95 due to length
# Removing P0DKL6 due to length
# Removing P0DMC5 due to length
# Removing P10040 due to length
# Removing P10180 due to length
# Removing P10351 due to length
# Removing P10408 due to length
# Removing P10443 due to length
# Removing P10493 due to length
# Removing P10961 due to length
# Removing P10964 due to length
# Removing P11035 due to length
# Removing P11046 due to length
# Removing P11075 due to length
# Removing P11103 due to length
# Removing P11154 due to length
# Removing P11352 due to non standard res
# Removing P11454 due to length
# Removing P11584 due to length
# Removing P11688 due to length
# Removing P11832 due to length
# Removing P11881 due to length
# Removing P11929 due to length
# Removing P11938 due to length
# Removing P12080 due to length
# Removing P12297 due to length
# Removing P12753 due to length
# Removing P12945 due to length
# Removing P13009 due to length
# Removing P13060 due to length
# Removing P13185 due to length
# Removing P13188 due to length
# Removing P13217 due to length
# Removing P13267 due to length
# Removing P13395 due to length
# Removing P13405 due to length
# Removing P13458 due to length
# Removing P13496 due to length
# Removing P13541 due to length
# Removing P13607 due to length
# Removing P13656 due to length
# Removing P13709 due to length
# Removing P13864 due to length
# Removing P14713 due to length
# Removing P14907 due to length
# Removing P14922 due to length
# Removing P15032 due to length
# Removing P15208 due to length
# Removing P15215 due to length
# Removing P15254 due to length
# Removing P15274 due to length
# Removing P15330 due to length
# Removing P15348 due to length
# Removing P15508 due to length
# Removing P15877 due to length
# Removing P15920 due to length
# Removing P16056 due to length
# Removing P16092 due to length
# Removing P16356 due to length
# Removing P16521 due to length
# Removing P16546 due to length
# Removing P16568 due to length
# Removing P16620 due to length
# Removing P16621 due to length
# Removing P16861 due to length
# Removing P16862 due to length
# Removing P17210 due to length
# Removing P17255 due to length
# Removing P17426 due to length
# Removing P17427 due to length
# Removing P17671 due to length
# Removing P17710 due to length
# Removing P17883 due to length
# Removing P17922 due to length
# Removing P18052 due to length
# Removing P18091 due to length
# Removing P18185 due to length
# Removing P18490 due to length
# Removing P18616 due to length
# Removing P18775 due to length
# Removing P18824 due to length
# Removing P18962 due to length
# Removing P19096 due to length
# Removing P19097 due to length
# Removing P19319 due to length
# Removing P19456 due to length
# Removing P19524 due to length
# Removing P19735 due to length
# Removing P19812 due to length
# Removing P20028 due to length
# Removing P20241 due to length
# Removing P20649 due to length
# Removing P20659 due to length
# Removing P20676 due to length
# Removing P20918 due to length
# Removing P20967 due to length
# Removing P21189 due to length
# Removing P21440 due to length
# Removing P21458 due to length
# Removing P21499 due to length
# Removing P21513 due to length
# Removing P21519 due to length
# Removing P21524 due to length
# Removing P21538 due to length
# Removing P21865 due to length
# Removing P22023 due to length
# Removing P22137 due to length
# Removing P22138 due to length
# Removing P22147 due to length
# Removing P22265 due to length
# Removing P22276 due to length
# Removing P22293 due to length
# Removing P22515 due to length
# Removing P22523 due to length
# Removing P22579 due to length
# Removing P22682 due to length
# Removing P22700 due to length
# Removing P22817 due to length
# Removing P22855 due to length
# Removing P23116 due to length
# Removing P23129 due to length
# Removing P23188 due to length
# Removing P23201 due to length
# Removing P23226 due to length
# Removing P23249 due to length
# Removing P23477 due to length
# Removing P23478 due to length
# Removing P23538 due to length
# Removing P23615 due to length
# Removing P23647 due to length
# Removing P23678 due to length
# Removing P23909 due to length
# Removing P23914 due to length
# Removing P24014 due to length
# Removing P24183 due to length
# Removing P24276 due to length
# Removing P24279 due to length
# Removing P24384 due to length
# Removing P24583 due to length
# Removing P24785 due to length
# Removing P24788 due to length
# Removing P25037 due to length
# Removing P25159 due to length
# Removing P25172 due to length
# Removing P25371 due to length
# Removing P25386 due to length
# Removing P25439 due to length
# Removing P25455 due to length
# Removing P25516 due to length
# Removing P25558 due to length
# Removing P25623 due to length
# Removing P25644 due to length
# Removing P25655 due to length
# Removing P25694 due to length
# Removing P25799 due to length
# Removing P25822 due to length
# Removing P25823 due to length
# Removing P25992 due to length
# Removing P25994 due to length
# Removing P26011 due to length
# Removing P26019 due to length
# Removing P26039 due to length
# Removing P26231 due to length
# Removing P26637 due to length
# Removing P26675 due to length
# Removing P26955 due to length
# Removing P27046 due to length
# Removing P27206 due to length
# Removing P27249 due to length
# Removing P27398 due to length
# Removing P27612 due to length
# Removing P27619 due to length
# Removing P27692 due to length
# Removing P28166 due to length
# Removing P28167 due to length
# Removing P28191 due to length
# Removing P28271 due to length
# Removing P28273 due to length
# Removing P28366 due to length
# Removing P28466 due to length
# Removing P28660 due to length
# Removing P28665 due to length
# Removing P28666 due to length
# Removing P28668 due to length
# Removing P29349 due to length
# Removing P29469 due to length
# Removing P29691 due to length
# Removing P29742 due to length
# Removing P30015 due to length
# Removing P30430 due to length
# Removing P30432 due to length
# Removing P30645 due to length
# Removing P30665 due to length
# Removing P30771 due to length
# Removing P30822 due to length
# Removing P30870 due to length
# Removing P30958 due to length
# Removing P30999 due to length
# Removing P31007 due to length
# Removing P31224 due to length
# Removing P31374 due to length
# Removing P31384 due to length
# Removing P31539 due to length
# Removing P31600 due to length
# Removing P31688 due to length
# Removing P31828 due to length
# Removing P32074 due to length
# Removing P32319 due to length
# Removing P32324 due to length
# Removing P32327 due to length
# Removing P32337 due to length
# Removing P32380 due to length
# Removing P32454 due to length
# Removing P32492 due to length
# Removing P32497 due to length
# Removing P32521 due to length
# Removing P32528 due to length
# Removing P32558 due to length
# Removing P32563 due to length
# Removing P32565 due to length
# Removing P32591 due to length
# Removing P32597 due to length
# Removing P32618 due to length
# Removing P32634 due to length
# Removing P32670 due to length
# Removing P32790 due to length
# Removing P32797 due to length
# Removing P32844 due to length
# Removing P32870 due to length
# Removing P32898 due to length
# Removing P33174 due to length
# Removing P33175 due to length
# Removing P33195 due to length
# Removing P33225 due to length
# Removing P33244 due to length
# Removing P33306 due to length
# Removing P33307 due to length
# Removing P33327 due to length
# Removing P33338 due to length
# Removing P33416 due to length
# Removing P33438 due to length
# Removing P33602 due to length
# Removing P33609 due to length
# Removing P33775 due to length
# Removing P33892 due to length
# Removing P33937 due to length
# Removing P34082 due to length
# Removing P34152 due to length
# Removing P34160 due to length
# Removing P34216 due to length
# Removing P34305 due to length
# Removing P34335 due to length
# Removing P34342 due to length
# Removing P34343 due to length
# Removing P34369 due to length
# Removing P34427 due to length
# Removing P34466 due to length
# Removing P34540 due to length
# Removing P34545 due to length
# Removing P34552 due to length
# Removing P34574 due to length
# Removing P34647 due to length
# Removing P34675 due to length
# Removing P34681 due to length
# Removing P34703 due to length
# Removing P34739 due to length
# Removing P35123 due to length
# Removing P35207 due to length
# Removing P35220 due to length
# Removing P35421 due to length
# Removing P35441 due to length
# Removing P35600 due to length
# Removing P35736 due to length
# Removing P35820 due to length
# Removing P35832 due to length
# Removing P35875 due to length
# Removing P35951 due to length
# Removing P35992 due to length
# Removing P36016 due to length
# Removing P36159 due to length
# Removing P36428 due to length
# Removing P36430 due to length
# Removing P36683 due to length
# Removing P36775 due to length
# Removing P37024 due to length
# Removing P37254 due to length
# Removing P37276 due to length
# Removing P37304 due to length
# Removing P37474 due to length
# Removing P37571 due to length
# Removing P37624 due to length
# Removing P37637 due to length
# Removing P37870 due to length
# Removing P37871 due to length
# Removing P37898 due to length
# Removing P38041 due to length
# Removing P38080 due to length
# Removing P38097 due to length
# Removing P38129 due to length
# Removing P38138 due to length
# Removing P38149 due to length
# Removing P38237 due to length
# Removing P38249 due to length
# Removing P38250 due to length
# Removing P38266 due to length
# Removing P38418 due to length
# Removing P38426 due to length
# Removing P38427 due to length
# Removing P38631 due to length
# Removing P38691 due to length
# Removing P38764 due to length
# Removing P38798 due to length
# Removing P38850 due to length
# Removing P38853 due to length
# Removing P38888 due to length
# Removing P38904 due to length
# Removing P38968 due to length
# Removing P38972 due to length
# Removing P38996 due to length
# Removing P39054 due to length
# Removing P39083 due to length
# Removing P39104 due to length
# Removing P39109 due to length
# Removing P39143 due to length
# Removing P39285 due to length
# Removing P39321 due to length
# Removing P39520 due to length
# Removing P39523 due to length
# Removing P39533 due to length
# Removing P39692 due to length
# Removing P39730 due to length
# Removing P39769 due to length
# Removing P39793 due to length
# Removing P39812 due to length
# Removing P39838 due to length
# Removing P39845 due to length
# Removing P39846 due to length
# Removing P39847 due to length
# Removing P39935 due to length
# Removing P39936 due to length
# Removing P39940 due to length
# Removing P39986 due to length
# Removing P40017 due to length
# Removing P40069 due to length
# Removing P40157 due to length
# Removing P40201 due to length
# Removing P40361 due to length
# Removing P40462 due to length
# Removing P40477 due to length
# Removing P40482 due to length
# Removing P40547 due to length
# Removing P40806 due to length
# Removing P40825 due to length
# Removing P40971 due to length
# Removing P41233 due to length
# Removing P41697 due to length
# Removing P41810 due to length
# Removing P41811 due to length
# Removing P41812 due to length
# Removing P41813 due to length
# Removing P41877 due to length
# Removing P42232 due to length
# Removing P42286 due to length
# Removing P42567 due to length
# Removing P42762 due to length
# Removing P42787 due to length
# Removing P42842 due to length
# Removing P42935 due to length
# Removing P43125 due to length
# Removing P43248 due to length
# Removing P43298 due to length
# Removing P43329 due to length
# Removing P43406 due to length
# Removing P43573 due to length
# Removing P43583 due to length
# Removing P43585 due to length
# Removing P43597 due to length
# Removing P43638 due to length
# Removing P45437 due to length
# Removing P45895 due to length
# Removing P46412 due to non standard res
# Removing P46549 due to length
# Removing P46557 due to length
# Removing P46675 due to length
# Removing P46682 due to length
# Removing P46863 due to length
# Removing P46867 due to length
# Removing P46889 due to length
# Removing P46918 due to length
# Removing P46923 due to length
# Removing P46935 due to length
# Removing P47035 due to length
# Removing P47047 due to length
# Removing P47068 due to length
# Removing P47116 due to length
# Removing P47135 due to length
# Removing P47169 due to length
# Removing P47825 due to length
# Removing P48053 due to length
# Removing P48361 due to length
# Removing P48377 due to length
# Removing P48415 due to length
# Removing P48526 due to length
# Removing P48582 due to length
# Removing P48591 due to length
# Removing P48608 due to length
# Removing P48722 due to length
# Removing P48754 due to length
# Removing P49095 due to length
# Removing P49135 due to length
# Removing P49657 due to length
# Removing P49687 due to length
# Removing P49735 due to length
# Removing P49849 due to length
# Removing P50077 due to length
# Removing P50101 due to length
# Removing P50111 due to length
# Removing P50535 due to length
# Removing P50896 due to length
# Removing P51432 due to length
# Removing P51592 due to length
# Removing P51612 due to length
# Removing P51829 due to length
# Removing P51830 due to length
# Removing P51834 due to length
# Removing P52034 due to length
# Removing P52172 due to length
# Removing P52431 due to length
# Removing P52479 due to length
# Removing P52633 due to length
# Removing P52645 due to length
# Removing P52647 due to length
# Removing P52850 due to length
# Removing P52918 due to length
# Removing P53008 due to length
# Removing P53015 due to length
# Removing P53076 due to length
# Removing P53091 due to length
# Removing P53094 due to length
# Removing P53115 due to length
# Removing P53125 due to length
# Removing P53278 due to length
# Removing P53316 due to length
# Removing P53438 due to length
# Removing P53552 due to length
# Removing P53569 due to length
# Removing P53585 due to length
# Removing P53622 due to length
# Removing P53753 due to length
# Removing P53762 due to length
# Removing P53848 due to length
# Removing P53858 due to length
# Removing P53893 due to length
# Removing P53914 due to length
# Removing P53920 due to length
# Removing P53953 due to length
# Removing P53978 due to length
# Removing P53995 due to length
# Removing P54159 due to length
# Removing P54276 due to length
# Removing P54358 due to length
# Removing P54362 due to length
# Removing P54394 due to length
# Removing P54609 due to length
# Removing P54623 due to length
# Removing P54786 due to length
# Removing P54811 due to length
# Removing P54812 due to length
# Removing P54860 due to length
# Removing P54889 due to length
# Removing P54936 due to length
# Removing P55162 due to length
# Removing P55163 due to length
# Removing P55824 due to length
# Removing P56399 due to length
# Removing P56785 due to length
# Removing P57080 due to length
# Removing P57780 due to length
# Removing P58252 due to length
# Removing P58281 due to length
# Removing P58390 due to length
# Removing P58501 due to length
# Removing P58854 due to length
# Removing P59240 due to length
# Removing P59470 due to length
# Removing P60240 due to length
# Removing P60330 due to length
# Removing P60882 due to length
# Removing P61671 due to length
# Removing P61707 due to length
# Removing P62342 due to non standard res
# Removing P62517 due to length
# Removing P63284 due to length
# Removing P70168 due to length
# Removing P70175 due to length
# Removing P70206 due to length
# Removing P70207 due to length
# Removing P70227 due to length
# Removing P70268 due to length
# Removing P70335 due to length
# Removing P70336 due to length
# Removing P70388 due to length
# Removing P70398 due to length
# Removing P70399 due to length
# Removing P70451 due to length
# Removing P70699 due to length
# Removing P70700 due to length
# Removing P70704 due to length
# Removing P76129 due to length
# Removing P76272 due to length
# Removing P76398 due to length
# Removing P76578 due to length
# Removing P76594 due to length
# Removing P77196 due to length
# Removing P77338 due to length
# Removing P77374 due to length
# Removing P77504 due to length
# Removing P77748 due to length
# Removing P77783 due to length
# Removing P81122 due to length
# Removing P82295 due to length
# Removing P83097 due to length
# Removing P83741 due to length
# Removing P89105 due to length
# Removing P90731 due to length
# Removing P90742 due to length
# Removing P90770 due to length
# Removing P90786 due to length
# Removing P90829 due to length
# Removing P90830 due to length
# Removing P90920 due to length
# Removing P91133 due to length
# Removing P91309 due to length
# Removing P91341 due to length
# Removing P91350 due to length
# Removing P91495 due to length
# Removing P91502 due to length
# Removing P91871 due to length
# Removing P91875 due to length
# Removing P91926 due to length
# Removing P91927 due to length
# Removing P92199 due to length
# Removing P92974 due to length
# Removing P93025 due to length
# Removing P93028 due to length
# Removing P93042 due to length
# Removing P93655 due to length
# Removing P93736 due to length
# Removing P94078 due to length
# Removing P94461 due to length
# Removing P94545 due to length
# Removing P96495 due to length
# Removing P96706 due to length
# Removing P97310 due to length
# Removing P97329 due to length
# Removing P97364 due to non standard res
# Removing P97412 due to length
# Removing P97434 due to length
# Removing P97449 due to length
# Removing P97484 due to length
# Removing P97798 due to length
# Removing P97820 due to length
# Removing P97868 due to length
# Removing P98081 due to length
# Removing P98195 due to length
# Removing Q00174 due to length
# Removing Q00402 due to length
# Removing Q00519 due to length
# Removing Q00547 due to length
# Removing Q00816 due to length
# Removing Q00955 due to length
# Removing Q00963 due to length
# Removing Q01149 due to length
# Removing Q01217 due to length
# Removing Q01279 due to length
# Removing Q01320 due to length
# Removing Q01454 due to length
# Removing Q01476 due to length
# Removing Q01477 due to length
# Removing Q01630 due to length
# Removing Q01853 due to length
# Removing Q01919 due to length
# Removing Q01989 due to length
# Removing Q02248 due to length
# ...
# Removing Q9NP73 due to length
# Removing Q9NQV6-2 due to length
# Removing Q9NRR4-2 due to length
# Removing Q9NSG2 due to length
# Removing Q9P1Q0-3 due to length
# Removing Q9P2P1 due to length
# Removing Q9UBC3-6 due to length
# Removing Q9UG01 due to length
# Removing Q9UKE5 due to length
# Removing Q9UKE5-3 due to length
# Removing Q9UKL3 due to length
# Removing Q9ULK2 due to length
# Removing Q9UPQ3-2 due to length
# Removing Q9UQL6 due to length
# Removing Q9Y4B6 due to length
# Removing Q9Y4E5-2 due to length
# Removing Q9Y4F3-3 due to length
# Removing Q9Y4K1 due to length
# Removing Q9Y6K1 due to length
# Removing A5PL33-3 due to length
# Removing A8MUN2 due to length
# Removing B9ZVT1 due to length
# Removing H0Y7Z1 due to length
# Removing O14526-2 due to length
# Removing O14924-2 due to length
# Removing O15013-7 due to length
# Removing O60336-4 due to length
# Removing O75182-2 due to length
# Removing O94953 due to length
# Removing O96028 due to length
# Removing P30414 due to length
# Removing P41226 due to length
# Removing P52179-2 due to length
# Removing P78312-6 due to length
# Removing Q07157-2 due to length
# Removing Q12766-2 due to length
# Removing Q2M389-2 due to length
# Removing Q2Q1W2 due to length
# Removing Q53TQ3 due to length
# Removing Q58EX7-2 due to length
# Removing Q5JSJ4 due to length
# Removing Q5T4T6 due to length
# Removing Q86UW6-2 due to length
# Removing Q8NAP3 due to length
# Removing Q8NDV3-2 due to length
# Removing Q92622-2 due to length
# Removing Q96PY6-2 due to length
# Removing Q9H4Z2-2 due to length
# Removing Q9NYV4 due to length
# Removing Q9UPU3 due to length
# Removing Q9Y6M7-6 due to length
# Removing A6NHB5 due to length
# Removing A7XYQ1 due to length
# Removing B1AKY9 due to length
# Removing B3KXW5 due to length
# Removing C9J240 due to length
# Removing C9JME2 due to length
# Removing E7ESX1 due to length
# Removing E7EWN3 due to length
# Removing E9PCD7 due to length
# Removing E9PD25 due to length
# Removing E9PDC3 due to length
# Removing E9PKC0 due to length
# Removing F5H8L4 due to length
# Removing F8VW41 due to length
# Removing G3V394 due to length
# Removing H0Y5D5 due to length
# Removing J3KQ40 due to length
# Removing M0R2Z9 due to length
# Removing O00533-2 due to length
# Removing O14974 due to length
# Removing O15015 due to length
# Removing O15034 due to length
# Removing O43490-4 due to length
# Removing O43520 due to length
# Removing O60449-2 due to length
# Removing O60486 due to length
# Removing O75095 due to length
# Removing O75128-3 due to length
# Removing O75161 due to length
# Removing O75170-4 due to length
# Removing O75185 due to length
# Removing O75891 due to length
# Removing O94827-5 due to length
# Removing O94851-6 due to length
# Removing O95425-2 due to length
# Removing O95622 due to length
# Removing P09619 due to length
# Removing P10643 due to length
# Removing P16144-2 due to length
# Removing P17301 due to length
# Removing P19021-6 due to length
# Removing P19367 due to length
# Removing P21860-4 due to length
# Removing P29400 due to length
# Removing P29590-11 due to length
# Removing P49321-3 due to length
# Removing P51805 due to length
# Removing P54753 due to length
# Removing P54764 due to length
# Removing P56545-2 due to length
# Removing P78524 due to length
# Removing P98155-2 due to length
# Removing P98194-2 due to length
# Removing Q12774 due to length
# Removing Q13733 due to length
# Removing Q13751 due to length
# Removing Q13753 due to length
# Removing Q4G0X9-3 due to length
# Removing Q4VCS5 due to length
# Removing Q5T5P2 due to length
# Removing Q5T8P6 due to length
# Removing Q6IA86-5 due to length
# Removing Q6N043-2 due to length
# Removing Q6P179-3 due to length
# Removing Q6UXG2-2 due to length
# Removing Q7RTX0 due to length
# Removing Q86TI0 due to length
# Removing Q86U86-5 due to length
# Removing Q86V15 due to length
# Removing Q86XP0 due to length
# Removing Q86XP1 due to length
# Removing Q8IV36-2 due to length
# Removing Q8IY17-5 due to length
# Removing Q8IZF0 due to length
# Removing Q8NDT2 due to length
# Removing Q96J92-3 due to length
# Removing Q96L96 due to length
# Removing Q99959-2 due to length
# Removing Q9BQT9 due to length
# Removing Q9BY89 due to length
# Removing Q9H3R0-4 due to length
# Removing Q9H4L7-2 due to length
# Removing Q9H6A9-2 due to length
# Removing Q9H6R4-4 due to length
# Removing Q9H7Z3 due to length
# Removing Q9HCG7 due to length
# Removing Q9NQW6-2 due to length
# Removing Q9NRZ9-2 due to length
# Removing Q9NV70 due to length
# Removing Q9P275 due to length
# Removing Q9UHF7 due to length
# Removing Q9UIU6 due to length
# Removing Q9UL18 due to length
# Removing Q9ULD9 due to length
# Removing Q9ULJ8 due to length
# Removing Q9UM54-5 due to length
# Removing Q9UPP1-4 due to length
# Removing Q9Y2I9 due to length
# Removing Q9Y5Y6 due to length
# Removing Q9Y666 due to length
# Removing Q9Y6N7-4 due to length
# Removing A7E2V4-5 due to length
# Removing D6RCC7 due to length
# Removing O15083 due to length
# Removing O75096 due to length
# Removing O94967-4 due to length
# Removing P06737 due to length
# Removing P12830 due to length
# Removing P52756 due to length
# Removing P56199 due to length
# Removing Q24JP5 due to length
# Removing Q5T0Z8 due to length
# Removing Q6L9W6 due to length
# Removing Q7Z3F1 due to length
# Removing Q8NBP0 due to length
# Removing Q8WUJ3-2 due to length
# Removing Q96RT1-4 due to length
# Removing Q96T21-2 due to length
# Removing Q9H5Y7 due to length
# Removing Q9NZJ5 due to length
# Removing A3KMH1-3 due to length
# Removing A6NEL2 due to length
# Removing O00754 due to length
# Removing O43491-4 due to length
# Removing O60437 due to length
# Removing O75128 due to length
# Removing O76041 due to length
# Removing O94979-6 due to length
# Removing P02452 due to length
# Removing P0C0L5 due to length
# Removing P0C7U0 due to length
# Removing P13671 due to length
# Removing P14543 due to length
# Removing P19827 due to length
# Removing P23508-2 due to length
# Removing P35568 due to length
# Removing P47989 due to length
# Removing P52790 due to length
# Removing P55157 due to length
# Removing P55265-3 due to length
# Removing Q01970-2 due to length
# Removing Q06033-2 due to length
# Removing Q06278 due to length
# Removing Q07075 due to length
# Removing Q12986-3 due to length
# Removing Q14596-2 due to length
# Removing Q14624 due to length
# Removing Q14C86-4 due to length
# Removing Q15746-2 due to length
# Removing Q4V348 due to length
# Removing Q5RHP9 due to length
# Removing Q6ZUJ8 due to length
# Removing Q7L7X3-3 due to length
# Removing Q7Z392-3 due to length
# Removing Q86UU0-4 due to length
# Removing Q8IXQ6-2 due to length
# Removing Q8N283 due to length
# Removing Q8TER0-5 due to length
# Removing Q8TEW0-5 due to length
# Removing Q8TEW8-5 due to length
# Removing Q92888-2 due to length
# Removing Q92954-3 due to length
# Removing Q96G01-3 due to length
# Removing Q96JE7 due to length
# Removing Q96P48-7 due to length
# Removing Q96PU5-3 due to length
# Removing Q96QZ7-3 due to length
# Removing Q9BYX4 due to length
# Removing Q9NP71-4 due to length
# Removing Q9UI17 due to length
# Removing Q9UL12 due to length
# Removing Q9ULD0 due to length
# Removing Q9Y4E8-2 due to length
# Removing P19022 due to length
# Removing B4E1Z4 due to length
# Removing E7EVG2 due to length
# Removing E9PK67 due to length
# Removing E9PKB0 due to length
# Removing F5GZZ9 due to length
# Removing F5H2B9 due to length
# Removing H0Y304 due to length
# Removing Q5VTI5 due to length
# Removing O43426-4 due to length
# Removing P29374-3 due to length
# Removing Q00653 due to length
# Removing Q15746-6 due to length
# Removing Q86UW7-3 due to length
# Removing Q8N3V7-2 due to length
# Removing Q8N4C8-4 due to length
# Removing Q8NDX5-2 due to length
# Removing Q9HCB6 due to length
# Removing Q9P2D0-2 due to length
# Removing E7EX83 due to length
# Removing O94979-3 due to length
# Removing Q14676-4 due to length
# Removing Q15075 due to length
# Removing Q15424 due to length
# Removing Q16787-4 due to length
# Removing Q5GLZ8-6 due to length
# Removing Q63HR2-2 due to length
# Removing Q7Z5K2-3 due to length
# Removing Q7Z5Q5 due to length
# Removing Q86SQ0 due to length
# Removing Q9BXU1-3 due to length
# Removing Q9BZL4 due to length
# Removing Q9NYF8-2 due to length
# Removing Q9Y2L5-2 due to length
# Removing F8W9S7 due to length
# Removing A1L390 due to length
# Removing P20810-6 due to length
# Removing P57737-2 due to length
# Removing Q58WW2-4 due to length
# Removing Q86SQ0-3 due to length
# Removing Q8N3P4-2 due to length
# Removing Q8TER5-4 due to length
# Removing Q8WWI1-3 due to length
# Removing Q9BYE9 due to length
# Removing A6NNK5 due to length
# Removing A6NC98 due to length
# Removing A8MQ14 due to length
# Removing B0I1T2 due to length
# Removing B4E3Q1 due to length
# Removing B8ZZI7 due to length
# Removing C9JE82 due to length
# Removing C9JXA2 due to length
# Removing E7EN19 due to length
# Removing E7EWW0 due to length
# Removing E9PSI1 due to length
# Removing F8VU11 due to length
# Removing F8W881 due to length
# Removing F8WE88 due to length
# Removing G5EA25 due to length
# Removing H0Y2M0 due to length
# Removing J3KPQ4 due to length
# Removing K7EIX2 due to length
# Removing K7ER95 due to length
# Removing O43295 due to length
# Removing O43861-2 due to length
# Removing O75694-2 due to length
# Removing O94906 due to length
# Removing O95786 due to length
# Removing O95980 due to length
# Removing P05106 due to length
# Removing P06213-2 due to length
# Removing P08575 due to length
# Removing P20020-5 due to length
# Removing P20701 due to length
# Removing P37275-3 due to length
# Removing P51531 due to length
# Removing P51828 due to length
# Removing P54886 due to length
# Removing P55283 due to length
# Removing Q14114 due to length
# Removing Q15542 due to length
# Removing Q15714 due to length
# Removing Q2VPB7 due to length
# Removing Q5CZ79 due to length
# Removing Q5HYA8-3 due to length
# Removing Q5SR47 due to length
# Removing Q5T0V0 due to length
# Removing Q5VU97 due to length
# Removing Q6P179 due to length
# Removing Q6PJG2 due to length
# Removing Q6UXD5-3 due to length
# Removing Q6V1X1-3 due to length
# Removing Q75QN2 due to length
# Removing Q76FK4-4 due to length
# Removing Q7Z6I6 due to length
# Removing Q7Z6P3 due to length
# Removing Q86TI0-2 due to length
# Removing Q86YV0 due to length
# Removing Q8IUX7 due to length
# Removing Q8IXT5 due to length
# Removing Q8IY21 due to length
# Removing Q8TD16-2 due to length
# Removing Q8TEQ8 due to length
# Removing Q8TEW0-7 due to length
# Removing Q92614-2 due to length
# Removing Q92626 due to length
# Removing Q92771 due to length
# Removing Q93084-2 due to length
# Removing Q96CN4-2 due to length
# Removing Q96FC9-3 due to length
# Removing Q99490-2 due to length
# Removing Q9BQF6-5 due to length
# Removing Q9BVI0 due to length
# Removing Q9BYX2-3 due to length
# Removing Q9HCL2 due to length
# Removing Q9NYU1 due to length
# Removing Q9P2K2 due to length
# Removing Q9UBL0 due to length
# Removing Q9UKW4 due to length
# Removing Q9UQP3 due to length
# Removing Q9Y2D5-6 due to length
# Removing O95427 due to length
# Removing Q13367 due to length
# Removing Q5VZ66 due to length
# Removing Q6ZRI6-2 due to length
# Removing Q7Z2K6 due to length
# Removing Q8IWW6-3 due to length
# Removing Q9BQI6 due to length
# Removing Q9ULI3 due to length
# Removing A6NFQ2-2 due to length
# Removing A6NIT2 due to length
# Removing B7Z765 due to length
# Removing C9J7I2 due to length
# Removing E7EPS8 due to length
# Removing E9PHA6 due to length
# Removing E9PMP7 due to length
# Removing H0Y2M6 due to length
# Removing H0YI08 due to length
# Removing J3KR88 due to length
# Removing J3QLU9 due to length
# Removing O15069 due to length
# Removing O15394 due to length
# Removing O75095-2 due to length
# Removing O75150-3 due to length
# Removing O76074 due to length
# Removing O94856-9 due to length
# Removing P00533 due to length
# Removing P0CG38 due to length
# Removing P12107-3 due to length
# Removing P12110 due to length
# Removing P12110-2 due to length
# Removing P12821-2 due to length
# Removing P16234 due to length
# Removing P19021 due to length
# Removing P23634-8 due to length
# Removing P32418-2 due to length
# Removing P35442 due to length
# Removing P40189 due to length
# Removing P52848 due to length
# Removing Q07092-2 due to length
# Removing Q13683-3 due to length
# Removing Q13873 due to length
# Removing Q13905-2 due to length
# Removing Q14112-2 due to length
# Removing Q14934-13 due to length
# Removing Q14C86-3 due to length
# Removing Q15147 due to length
# Removing Q16832 due to length
# Removing Q2M1Z3 due to length
# Removing Q4L180-3 due to length
# Removing Q53EP0 due to length
# Removing Q53TS8-4 due to length
# Removing Q58DX5 due to length
# Removing Q58WW2-3 due to length
# Removing Q5HYK7 due to length
# Removing Q5TEA3 due to length
# Removing Q5VWU8 due to length
# Removing Q6V1X1-2 due to length
# Removing Q6ZMZ3-2 due to length
# Removing Q76M96 due to length
# Removing Q7Z6E9-4 due to length
# Removing Q86W92-2 due to length
# Removing Q86WG5 due to length
# Removing Q8N163-2 due to length
# Removing Q8NDV7-6 due to length
# Removing Q8TEJ3 due to length
# Removing Q92974-2 due to length
# Removing Q96CC6 due to length
# Removing Q96CN4 due to length
# Removing Q96PE1-2 due to length
# Removing Q96Q06-2 due to length
# Removing Q96QB1 due to length
# Removing Q96QZ7-4 due to length
# Removing Q96RT1-5 due to length
# Removing Q99650 due to length
# Removing Q9H0X9-2 due to length
# Removing Q9HCE3 due to length
# Removing Q9HCH5-6 due to length
# Removing Q9NQ66-2 due to length
# Removing Q9NZ08-2 due to length
# Removing Q9NZ56 due to length
# Removing Q9P0K7-4 due to length
# Removing Q9P2E7 due to length
# Removing Q9UHB7-2 due to length
# Removing Q9UKE5-5 due to length
# Removing Q9UKU6 due to length
# Removing Q9UP79 due to length
# Removing Q9UPQ0-10 due to length
# Removing Q9Y2E5 due to length
# Removing Q9Y4B5 due to length
# Removing D6RGD1 due to length
# Removing E9PF55 due to length
# Removing E9PJK5 due to length
# Removing F8WAT8 due to length
# Removing J3KQR7 due to length
# Removing O15061 due to length
# Removing P23634-5 due to length
# Removing P26232-3 due to length
# Removing Q04912-2 due to length
# Removing Q13018-2 due to length
# Removing Q5M775-4 due to length
# Removing Q6T4R5-4 due to length
# Removing Q86UL8-2 due to length
# Removing Q8N1W1-3 due to length
# Removing Q8NEY1-2 due to length
# Removing Q9HCK4 due to length
# Removing Q9UKX5 due to length
# Removing B7WPD9 due to length
# Removing Q9BXB1-2 due to length
# Removing E9PD35 due to length
# Removing G3V511 due to length
# Removing Q5JSH3-4 due to length
# Removing Q5T5P2-2 due to length
# Removing Q86SQ4-2 due to length
# Removing Q9ULI3-2 due to length
# Removing P39180 due to length
# Removing P52028 due to length
# Removing Q53VU9 due to length
# Removing Q53VY2 due to length
# Removing Q53VY8 due to length
# Removing Q53WG2 due to length
# Removing Q5SGX1 due to length
# Removing Q5SH56 due to length
# Removing Q5SI74 due to length
# Removing Q5SJ45 due to length
# Removing Q5SJJ2 due to length
# Removing Q5SJJ4 due to length
# Removing Q5SJV3 due to length
# Removing Q5SK21 due to length
# Removing Q5SKM5 due to length
# Removing Q5SL15 due to length
# Removing Q5SLV8 due to length
# Removing Q5SLY5 due to length
# Removing Q5SM69 due to length
# Removing P06786 due to length
# Removing P22082 due to length
# Removing P32386 due to length
# Removing P33418 due to length
# Removing P35729 due to length
# Removing P37297 due to length
# Removing P38810 due to length
# Removing P39685 due to length
# Removing P40318 due to length
# Removing P40965 due to length
# Removing P43612 due to length
# Removing P46970 due to length
# Removing P53009 due to length
# Removing P53104 due to length
# Removing P53254 due to length
# Removing Q04264 due to length
# Removing Q12275 due to length
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[43], line 30
#      26         da  = row[1]["Data_set"]
#      28         f.write(f">{id_} {da} {TM}\n{seq}\n")
# ---> 30 if any(amino in sequence for amino in NON_STANDARD_AMINO):
#      31     raise ValueError (f"Sequences can not contain non standard amino acids")
#
# Cell In[43], line 30, in <genexpr>(.0)
#      26         da  = row[1]["Data_set"]
#      28         f.write(f">{id_} {da} {TM}\n{seq}\n")
# ---> 30 if any(amino in sequence for amino in NON_STANDARD_AMINO):
#      31     raise ValueError (f"Sequences can not contain non standard amino acids")
#
# NameError: name 'sequence' is not defined

# %%
! grep "^>" ../data/all_tms.fasta| wc
# Out:
#   68493  205479 2000956

# %%
! grep "^>" ../data/all_tms_noredun.fasta| wc
# Out:
#   40193  120579 1347777

# %%
! grep "^>" ../data/all_tms_noredun_780.fasta| wc
# Out:
#   33568  100704  966311
